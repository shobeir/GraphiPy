# %%
from usde.usde import USDE

# %%
usde = USDE()

# %%
# The pinterest API needs access token

pinterest_api = {
    "access_token": 'ApjqribsCiB5LOgIZrqv7LN6nc7qFWM2JysPtGRFW-yQrkBflAvtgDAAAaRkRVvsxELgUQwAAAAA'
}

# %%
pinterest = usde.get_pinterest(pinterest_api)

# %%
# You can get user info if you know the username
single_user = pinterest.fetch_pinterest_user_by_username(usde.create_graph(), "uscdiglib")
# Out:
# {'message': 'You have exceeded your rate limit. Try again later.', 'type': 'api'}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-34db33efd818> in <module>()
#       1 # You can get user info if you know the username
# ----> 2 single_user = pinterest.fetch_pinterest_user_by_username(usde.create_graph(), "uscdiglib")
#
# ~/Documents/CSCI401/USDE/usde/api/pinterest/pinterest_api.py in fetch_pinterest_user_by_username(self, graph, username)
#      49         result = self.get_single_user(username)
#      50         user = PinterestUser(result["data"])
# ---> 51         graph.create_node(user)
#      52         return graph
#      53
#
# KeyError: 'data'

# %%
# You can get the dataframe generated by fetch_pinterest_user_by_username() from Pandas
single_user_df = single_user.get_df("user")

# %%
# Display the dataframe
single_user_df.head()
# Out:
#                   _id                 Label label_attribute  \
# 0  341640459140994416  USC Digital Library             user
#
#                                                  bio           first_name  \
# 0  The USC Digital Library supports teaching, lea...  USC Digital Library
#
#   last_name account_type                                   url  \
# 0               business  https://www.pinterest.com/uscdiglib/
#
#                                            image_url           created_at  \
# 0  https://i.pinimg.com/60x60_RS/d1/e8/74/d1e8748...  2012-11-22T00:33:54
#
#   pins_count following_count followers_count boards_count
# 0       3568             210            2340           78

# %%
# You can get board info if you know the board url
single_board = pinterest.fetch_pinterest_board_by_url(usde.create_graph(), "uscdiglib/architectural-teaching-slide-collection")
# Out:
# {'message': 'You have exceeded your rate limit. Try again later.', 'type': 'api'}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-02f8f032011b> in <module>()
#       1 # You can get board info if you know the board url
# ----> 2 single_board = pinterest.fetch_pinterest_board_by_url(usde.create_graph(), "uscdiglib/architectural-teaching-slide-collection")
#
# ~/Documents/CSCI401/USDE/usde/api/pinterest/pinterest_api.py in fetch_pinterest_board_by_url(self, graph, board_url)
#      57         print(board_result)
#      58         board = PinterestBoard(board_result["data"])
# ---> 59         graph.create_node(board)
#      60
#      61         creator_username = board_result["data"]["creator"]["url"].split('/')[3]
#
# KeyError: 'data'

# %%
single_board_df = single_board.get_df("board")
single_board_creator_df = single_board.get_df("user")
single_board_pins_df = single_board.get_df("pin")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-c89c52e6bbfb> in <module>()
# ----> 1 single_board_df = single_board.get_df("board")
#       2 single_board_creator_df = single_board.get_df("user")
#       3 single_board_pins_df = single_board.get_df("pin")
#
# NameError: name 'single_board' is not defined

# %%
single_board_df.head()
single_board_creator_df.head()
single_board_pins_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-ce876436d2ad> in <module>()
# ----> 1 single_board_df.head()
#
# NameError: name 'single_board_df' is not defined

# %%
# You can also get all the node dataframes available from the query
sb_nodes = single_board.get_nodes()

# To find out list of available nodes
print(sb_nodes.keys())
