# %%
from usde.usde import USDE

# %%
usde = USDE()

# %%
# The twitter API needs these credentials

twitter_api_credentials = {
    "consumer_key": ' ',
    "consumer_secret": ' ',
    "access_token": ' ',
    "token_secret": ' '
}

# %%
twitter = usde.get_twitter(twitter_api_credentials)

# %% [markdown]
# # Search tweets by keyword

# %%
keyword = "USC"
limit = 5
# call fetch_tweets_by_topic(graph, keyword, limit=15), which will return a graph containing: 
# nodes of tweets, nodes of creators, nodes of original tweet if the tweet returned retweet/quote another tweet
# edges between tweet and creator, tweet and tweet(retweet/quote relationship)
tweets_graph = twitter.fetch_tweets_by_topic(usde.create_graph(), keyword, 5)

# %%
# we can get a list of tweets
tweets_df = tweets_graph.get_df("tweet")
tweets_df.head()
# Out:
#                     id                      Label label_attribute  \
# 0  1060785505036492800  tweet_1060785505036492800           tweet
# 1  1060707577691099142  tweet_1060707577691099142           tweet
# 2  1060785495196618752  tweet_1060785495196618752           tweet
# 3  1060785489240719360  tweet_1060785489240719360           tweet
# 4  1060785484614356993  tweet_1060785484614356993           tweet
#
#                        created_at  \
# 0  Fri Nov 09 06:45:47 +0000 2018
# 1  Fri Nov 09 01:36:08 +0000 2018
# 2  Fri Nov 09 06:45:45 +0000 2018
# 3  Fri Nov 09 06:45:43 +0000 2018
# 4  Fri Nov 09 06:45:42 +0000 2018
#
#                                                 text  \
# 0  RT @jedshug: Matt Whitaker's appointment as Ac...
# 1  Matt Whitaker's appointment as Acting Attorney...
# 2  30 year old s/p ACL reconstruction with menisc...
# 3  @uscpsycho @TrojanSuzanneR USC Recruiting is a...
# 4  RT @jedshug: Matt Whitaker's appointment as Ac...
#
#                                               source truncated  \
# 0  <a href="http://twitter.com/download/iphone" r...     False
# 1  <a href="http://twitter.com" rel="nofollow">Tw...      True
# 2  <a href="http://twitter.com/download/iphone" r...      True
# 3  <a href="http://twitter.com/download/iphone" r...      True
# 4  <a href="http://twitter.com" rel="nofollow">Tw...     False
#
#   is_quote_status retweet_count favorite_count lang hashtags  \
# 0           False          1551              0   en       []
# 1           False          1551           3023   en       []
# 2           False             0              0   en       []
# 3           False             0              0   en       []
# 4           False          1551              0   en       []
#
#                         urls media                user_mentions
# 0                         []    {}                    [jedshug]
# 1  [https://t.co/ToPMQ7FFiJ]    {}                           []
# 2  [https://t.co/TUNyEwhzgD]    {}                           []
# 3  [https://t.co/kFziv78z0y]    {}  [uscpsycho, TrojanSuzanneR]
# 4                         []    {}                    [jedshug]

# %%
# for each tweet, we can get general information:
tweets_df.iloc[0]
# Out:
# id                                               1060785505036492800
# Label                                      tweet_1060785505036492800
# label_attribute                                                tweet
# created_at                            Fri Nov 09 06:45:47 +0000 2018
# text               RT @jedshug: Matt Whitaker's appointment as Ac...
# source             <a href="http://twitter.com/download/iphone" r...
# truncated                                                      False
# is_quote_status                                                False
# retweet_count                                                   1551
# favorite_count                                                     0
# lang                                                              en
# hashtags                                                          []
# urls                                                              []
# media                                                             {}
# user_mentions                                              [jedshug]
# Name: 0, dtype: object

# %%
# we also get the creator of each tweet at the same time
creators_df = tweets_graph.get_df("user")
creators_df.head()
# Out:
#                  name                  id               Label label_attribute  \
# 0         incantica 🦋           555456256         incantica 🦋            user
# 1  Adrian Chavez, SPT  948609429875773440  Adrian Chavez, SPT            user
# 2    fight on forever            19522014    fight on forever            user
# 3      Wendi Jo  🤓☕️🥄            38382552      Wendi Jo  🤓☕️🥄            user
# 4              Johnny  832893324591632384              Johnny            user
#
#       screen_name         location   url  \
# 0        ticainca                   None
# 1      AC_SPT_USC  Los Angeles, CA  None
# 2     gouxforever                   None
# 3  CrankyDiplomat   City Beautiful  None
# 4     johnny12976                   None
#
#                                          description protected verified  \
# 0               Reader; Traveler; Advocate; Resister     False    False
# 1                                                        False    False
# 2  USC alum 1982. First USC football game 1962 - ...     False    False
# 3  Ninja warrior princess, #writer, #storyteller,...     False    False
# 4                                                        False    False
#
#          ...         favourites_count statuses_count  \
# 0        ...                    33627           4237
# 1        ...                       40             28
# 2        ...                    13895          30932
# 3        ...                    15998          15188
# 4        ...                    70578          76077
#
#                        created_at geo_enabled lang profile_background_color  \
# 0  Mon Apr 16 21:59:44 +0000 2012       False   en                   C0DEED
# 1  Wed Jan 03 17:38:07 +0000 2018       False   en                   F5F8FA
# 2  Mon Jan 26 05:39:00 +0000 2009        True   en                   C0DEED
# 3  Thu May 07 06:10:43 +0000 2009       False   en                   9AE4E8
# 4  Sat Feb 18 10:03:37 +0000 2017       False   en                   F5F8FA
#
#                        profile_background_image_url  \
# 0  http://abs.twimg.com/images/themes/theme1/bg.png
# 1                                              None
# 2  http://abs.twimg.com/images/themes/theme1/bg.png
# 3  http://abs.twimg.com/images/themes/theme1/bg.png
# 4                                              None
#
#                                    profile_image_url profile_link_color  \
# 0  http://pbs.twimg.com/profile_images/8554272204...             1DA1F2
# 1  http://pbs.twimg.com/profile_images/9620870993...             1DA1F2
# 2  http://pbs.twimg.com/profile_images/1002792148...             1DA1F2
# 3  http://pbs.twimg.com/profile_images/1058522760...             E81C4F
# 4  http://pbs.twimg.com/profile_images/9911905652...             1DA1F2
#
#   profile_text_color
# 0             333333
# 1             333333
# 2             333333
# 3             333333
# 4             333333
#
# [5 rows x 23 columns]

# %%
creators_df.screen_name
# Out:
# 0          ticainca
# 1        AC_SPT_USC
# 2       gouxforever
# 3    CrankyDiplomat
# 4       johnny12976
# Name: screen_name, dtype: object

# %% [markdown]
# # Get one user's followers by screen name

# %%
screenname = "AC_SPT_USC"
followers_limit = 3
# call fecth_followers_by_screenname(graph, screenname, limit=15), which will return a graph containing:
# node of user itself and nodes of followers
# edges between user and its followers
followers_graph = twitter.fecth_followers_by_screenname(usde.create_graph(), screenname, followers_limit)

# %%
# we can get list of nodes
nodes = followers_graph.get_nodes()
# we can print type of nodes:
print(nodes.keys())
# Out:
# dict_keys(['user'])

# %%
# we get list of nodes includes a user node and three followers nodes
nodes["user"].head()
# Out:
#                  name                  id               Label label_attribute  \
# 0  Adrian Chavez, SPT  948609429875773440  Adrian Chavez, SPT            user
# 1    Jennifer Venegas  948709661498261504    Jennifer Venegas            user
# 2   Jason Falvey, PhD           258586356   Jason Falvey, PhD            user
# 3              Rafael  939556146427322368              Rafael            user
#
#    screen_name         location   url  \
# 0   AC_SPT_USC  Los Angeles, CA  None
# 1  JVenegas210                   None
# 2   JRayFalvey    New Haven, CT  None
# 3      relWReX     Fillmore, CA  None
#
#                                          description protected verified  \
# 0                                                        False    False
# 1                                                        False    False
# 2  DPT, PhD| Board-certified Geriatric PT| Post-d...     False    False
# 3                                                        False    False
#
#          ...         favourites_count statuses_count  \
# 0        ...                       40             28
# 1        ...                        8             22
# 2        ...                     3287           4103
# 3        ...                      414             71
#
#                        created_at geo_enabled lang profile_background_color  \
# 0  Wed Jan 03 17:38:07 +0000 2018       False   en                   F5F8FA
# 1  Thu Jan 04 00:16:24 +0000 2018       False   en                   F5F8FA
# 2  Mon Feb 28 01:36:50 +0000 2011        True   en                   022330
# 3  Sat Dec 09 18:03:36 +0000 2017       False   en                   F5F8FA
#
#                         profile_background_image_url  \
# 0                                               None
# 1                                               None
# 2  http://abs.twimg.com/images/themes/theme15/bg.png
# 3                                               None
#
#                                    profile_image_url profile_link_color  \
# 0  http://pbs.twimg.com/profile_images/9620870993...             1DA1F2
# 1  http://pbs.twimg.com/profile_images/1034972990...             1DA1F2
# 2  http://pbs.twimg.com/profile_images/1048209465...             0084B4
# 3  http://pbs.twimg.com/profile_images/1060739825...             1DA1F2
#
#   profile_text_color
# 0             333333
# 1             333333
# 2             333333
# 3             333333
#
# [4 rows x 23 columns]

# %%
# we can also get a list of edges
edges = followers_graph.get_edges()
# we can print type of edges:
print(edges.keys())
# Out:
# dict_keys(['follow', 'followed by'])

# %%
# we get list of edges between user node and follower nodes: follower -> user
edges["followed by"].head()
# Out:
#                Source              Target        Label label_attribute  \
# 0  948609429875773440  948709661498261504  FOLLOWED BY     FOLLOWED BY
# 1  948609429875773440           258586356  FOLLOWED BY     FOLLOWED BY
# 2  948609429875773440  939556146427322368  FOLLOWED BY     FOLLOWED BY
#
#                                                 id
# 0  948609429875773440948709661498261504FOLLOWED BY
# 1           948609429875773440258586356FOLLOWED BY
# 2  948609429875773440939556146427322368FOLLOWED BY

# %% [markdown]
# # Get one user's followers by screen name

# %%
# we can also call fecth_friends_by_screenname(graph, screenname, limit=15), which will return a graph containing:
# node of user itself and nodes of followers
# edges between user and its friends
friends_limit = 3
friends_graph = twitter.fecth_friends_by_screenname(usde.create_graph(), screenname, friends_limit)

# %% [markdown]
# # Get single user's information by screen name

# %%
# We can also call fetch_user_by_screenname(self, graph, screenname), which will return a graph containig a user node:
single_user_graph = twitter.fetch_user_by_screenname(usde.create_graph(), screenname)

# %% [markdown]
# # Get single tweet's information by tweet id

# %%
# We can also call fetch_tweet_by_id(self, graph, id), which will return a graph containig a tweet node:
id = 1060785505036492800
single_tweet_graph = twitter.fetch_tweet_by_id(usde.create_graph(), id)

# %% [markdown]
# # Export a graph to CSV file

# %%
# We can call export_all_CSV() on the graph desired
# then graph can be showed via gephi, cytoscape, etc. takes CSV files

tweets_graph.export_all_CSV("tweets_searched_by_USC")

# %%
# We cam also specify the dataframes we want to export by using the .export_CSV() function
